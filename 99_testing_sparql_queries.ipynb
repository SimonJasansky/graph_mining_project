# %%
import rdflib
  
filename = "output.ttl"

g = rdflib.Graph()

g.parse(filename, format='ttl')

query = """

SELECT *
WHERE {
    # ?p ?s ?o
}

"""

qres = g.query(query)

for row in qres :
        print("%s" % row)
# Out:
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#float, Converter=<class 'float'>
# Traceback (most recent call last):
#   File "c:\Users\sjasa\anaconda3\lib\site-packages\rdflib\term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
# ValueError: could not convert string to float: 'MULTIPOINT (-101.8794642 54.7748162)'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#float, Converter=<class 'float'>
# Traceback (most recent call last):
#   File "c:\Users\sjasa\anaconda3\lib\site-packages\rdflib\term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
# ValueError: could not convert string to float: 'MULTIPOINT (76.2084138 14.2235254)'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#float, Converter=<class 'float'>
# Traceback (most recent call last):
# ...
